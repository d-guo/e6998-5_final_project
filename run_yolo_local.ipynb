# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=detection_data.yaml epochs=10 batch=32
# Out:
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-1.13.1 CPU
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=detection_data.yaml epochs=5 batch=4
# Out:
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-1.13.1 CPU
# ...
